# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(
    action="ignore",
    message=".*Unverified HTTPS.*",
)

# %%
# Importing & Reading the dataset 📝
df = pd.read_csv('/Users/apple/Downloads/TV_Final.csv')

# %% [markdown]
# # EDA 🔍

# %%
df.shape
# Out:
# (912, 7)

# %%
df.head()
# Out:
#      Brand     Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA   Ultra HD LED     55          37999           54990
# 1     TCL   QLED Ultra HD     55          52999          129990
# 2  realme          HD LED     32          13999           17999
# 3      Mi          HD LED     32          14999           19999
# 4  realme          HD LED     32          12999           21999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 1          Android     4.4
# 2          Android     4.3
# 3          Android     4.4
# 4          Android     4.3

# %%
df['Brand']=df['Brand'].replace(['Samsung'],'SAMSUNG')

# %%
df.dtypes
# Out:
# Brand                object
# Resolution           object
# Size                  int64
# Selling Price         int64
# Original Price        int64
# Operating System     object
# Rating              float64
# dtype: object

# %%
df.nunique()
# Out:
# Brand                58
# Resolution            5
# Size                 27
# Selling Price       515
# Original Price      455
# Operating System      7
# Rating               25
# dtype: int64

# %%
df['Brand'].nunique()
# Out:
# 58

# %%
df['Resolution'].unique()
# Out:
# array(['Ultra HD LED', 'QLED Ultra HD', 'HD LED', 'Full HD LED',
#        'HD Plasma'], dtype=object)

# %%
df['Operating System'].unique()
# Out:
# array(['VIDAA', 'Android', 'Linux', nan, 'Tizen', 'WebOS', 'HomeOS',
#        'FireTV OS'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Brand                 0
# Resolution            0
# Size                  0
# Selling Price         0
# Original Price        0
# Operating System     11
# Rating              220
# dtype: int64

# %%
#color palette for this notebook
colors = ["#EF233C","#eb5e28","#d68c45","#00bbf9","#274c77","#3a0ca3"]
palette = sns.color_palette(palette = colors)

sns.palplot(palette, size =1)
plt.show()

# %%
# count of products by Resolution
df['Brand'].groupby(df['Resolution']).count().sort_values(ascending=False)
# Out:
# Resolution
# Ultra HD LED     399
# HD LED           229
# Full HD LED      220
# QLED Ultra HD     60
# HD Plasma          4
# Name: Brand, dtype: int64

# %%
# Device Type distribution

labels = 'Ultra HD LED', 'QLED Ultra HD', 'HD LED', 'Full HD LED','HD Plasma'
sizes = [399,229,220,60,4]
fig, ax = plt.subplots(figsize=(10,6))
fig.set_facecolor('white')
ax.pie(sizes, labels=labels, colors=["#EF233C","#eb5e28","#3a0ca3","#d68c45","#00bbf9"],autopct='%1.1f%%', startangle=60,textprops={'color':'black','weight':'bold','fontsize':12.5})
ax.axis('equal')
plt.show()

# %%
#Which are the top 5 brands for TV?
df['Brand'].groupby(df['Brand']).count().sort_values(ascending=False).iloc[:5]
# Out:
# Brand
# SAMSUNG      146
# LG           122
# SONY          62
# TCL           44
# Panasonic     30
# Name: Brand, dtype: int64

# %%
#Brands and Resolution
sns.set_style('white')
plt.figure(figsize=(10,7))
sns.countplot(y="Brand", hue="Resolution", data=df, palette=colors,order=df["Brand"].value_counts().iloc[:5].index)
# Out:
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/1362929362.py:4: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.countplot(y="Brand", hue="Resolution", data=df, palette=colors,order=df["Brand"].value_counts().iloc[:5].index)
# <Axes: xlabel='count', ylabel='Brand'>

# %%
#Are TVs with higher ratings more expensive or do expensive TVs from well-known brands have higher ratings indicating premium quality?
round(df.groupby('Brand')['Rating'].mean().sort_values(ascending=False),1)
# Out:
# Brand
# SONY                4.5
# OnePlus             4.4
# Hisense             4.4
# Haier               4.4
# Vu                  4.4
# TOSHIBA             4.4
# MOTOROLA            4.3
# Mi                  4.3
# Compaq              4.3
# Onida               4.3
# Thomson             4.3
# Onix                4.3
# Dektron             4.3
# KODAK               4.3
# iFFALCON by TCL     4.3
# LG                  4.3
# realme              4.3
# MarQ by Flipkart    4.3
# Nokia               4.3
# SAMSUNG             4.3
# Coocaa              4.2
# Blaupunkt           4.2
# Weston              4.2
# TCL                 4.2
# Sanyo               4.2
# Infinix             4.2
# Intex               4.2
# Panasonic           4.2
# IMPEX               4.1
# Croma               4.1
# Sansui              4.1
# Micromax            4.1
# PHILIPS             4.1
# HUIDI               4.1
# CloudWalker         4.1
# Candes              4.1
# Lloyd               4.1
# JVC                 4.0
# DETEL               4.0
# LumX                4.0
# Acer                3.9
# RGL                 3.9
# G-TEN               3.8
# T-Series            3.8
# Maser               3.8
# Adsun               3.8
# BPL                 3.7
# Dyanora             3.7
# Sharp               3.4
# AISEN               3.3
# MURPHY              3.1
# Skyworth            3.0
# Akai                NaN
# KRISONS             NaN
# Oxygen              NaN
# Power Guard         NaN
# Sun King            NaN
# VG                  NaN
# Name: Rating, dtype: float64

# %%
# Rating vs Selling Price
#filter by Known Brands
list1 = ["SONY","OnePlus","Haier","Vu","TOSHIBA","MOTOROLA","Mi","Compaq","Onida","Thomson",
        "KODAK","LG","realme","SAMSUNG","Nokia","Panasonic","Sansui","Micromax","PHILIPS","Samsung","JVC"]

list2 = ["Hisense","Thomson","Onix","KODAK","Dektron","iFFALCON by TCL","MarQ by Flipkart","Nokia","Coocaa","Blaupunkt","Weston","TCL",
        "Infinix","Sanyo","Intex","IMPEX","Croma","HUIDI","CloudWalker","Lloyd", 
        "Candes","Detel","LumX"]
series1 = df["Brand"].isin(list1)
series2 = df["Brand"].isin(list2)
df_f1= df[series1]
df_f2= df[series2]
fig, axs = plt.subplots(ncols=2,figsize=(20,5))
ax1 = sns.stripplot(x="Rating", y="Selling Price", data=df_f1,hue="Brand", palette=colors,ax=axs[0])
ax2 = sns.stripplot(x="Rating", y="Selling Price", data=df_f2,hue="Brand", palette=colors,ax=axs[1])
# Out:
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/2716582731.py:14: UserWarning:
# The palette list has fewer values (6) than needed (11) and will cycle, which may produce an uninterpretable plot.
#   ax1 = sns.stripplot(x="Rating", y="Selling Price", data=df_f1,hue="Brand", palette=colors,ax=axs[0])
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/2716582731.py:15: UserWarning:
# The palette list has fewer values (6) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   ax2 = sns.stripplot(x="Rating", y="Selling Price", data=df_f2,hue="Brand", palette=colors,ax=axs[1])

# %%
import altair as alt
alt.Chart(df).mark_point(filled=True,size=40).encode(
    x='Original Price',
    y='Selling Price',
    color='Brand',
    tooltip=['Brand', 'Selling Price', 'Original Price']
).interactive()
# Out:
# alt.Chart(...)

# %%
sns.barplot(x=df['Resolution'], y=df['Selling Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()
# Out:
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/4133290183.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Resolution'], y=df['Selling Price'],palette=colors)
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/4133290183.py:1: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.barplot(x=df['Resolution'], y=df['Selling Price'],palette=colors)

# %%
# Brandwise Mean Selling prices
df.groupby('Brand')['Selling Price'].mean().sort_values(ascending=False).apply(np.ceil)
# Out:
# Brand
# Sharp               149672.0
# SAMSUNG             107035.0
# LG                   96915.0
# Hisense              89796.0
# SONY                 89343.0
# TCL                  55799.0
# iFFALCON by TCL      54235.0
# Panasonic            53494.0
# Akai                 52003.0
# OnePlus              47376.0
# Vu                   46650.0
# Compaq               45999.0
# Sanyo                45499.0
# Weston               43390.0
# Oxygen               40327.0
# Nokia                38863.0
# TOSHIBA              38853.0
# MOTOROLA             38399.0
# Sansui               37672.0
# Haier                36617.0
# AISEN                35463.0
# BPL                  34618.0
# Onix                 34217.0
# Lloyd                34162.0
# PHILIPS              34114.0
# JVC                  32497.0
# CloudWalker          32332.0
# Acer                 31665.0
# Mi                   30788.0
# Power Guard          30510.0
# Onida                29708.0
# IMPEX                28820.0
# Intex                27341.0
# Micromax             26870.0
# Thomson              25249.0
# Sun King             24999.0
# LumX                 24859.0
# Coocaa               24443.0
# realme               24428.0
# Blaupunkt            23713.0
# KODAK                23666.0
# Croma                22366.0
# VG                   19493.0
# HUIDI                18166.0
# DETEL                18111.0
# MarQ by Flipkart     17749.0
# T-Series             17180.0
# Infinix              17166.0
# G-TEN                16919.0
# Dyanora              15516.0
# Adsun                15221.0
# Candes               13416.0
# MURPHY               12818.0
# RGL                  11107.0
# Skyworth              8659.0
# Maser                 7499.0
# Dektron               6724.0
# KRISONS               5866.0
# Name: Selling Price, dtype: float64

# %%
#filter dataframe
df_p1=df_f1[(df_f1["Selling Price"] >=10000) & (df_f1["Selling Price"] <= 100000)]
df_p1.iloc[:2]
# Out:
#      Brand    Resolution  Size   Selling Price  Original Price  \
# 0  TOSHIBA  Ultra HD LED     55          37999           54990
# 5  OnePlus        HD LED     32          15999           19999
#
#   Operating System  Rating
# 0            VIDAA     4.3
# 5          Android     4.3

# %%
#Box plot to denote average selling prices
fig, ax = plt.subplots(figsize=(20,5))
ax = sns.boxplot(x="Brand", y="Selling Price", data=df_p1,palette=colors)
# Out:
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/686656634.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x="Brand", y="Selling Price", data=df_p1,palette=colors)
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/686656634.py:3: UserWarning:
# The palette list has fewer values (6) than needed (11) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.boxplot(x="Brand", y="Selling Price", data=df_p1,palette=colors)

# %%
#filter dataframe
df_p2=df_f2[(df_f2["Selling Price"] >=10000) & (df_f2["Selling Price"] <= 100000)]
df_p2.iloc[:2]
# Out:
#       Brand    Resolution  Size   Selling Price  Original Price  \
# 11  Hisense  Ultra HD LED     55          36999           49990
# 15  Hisense  Ultra HD LED     70          89999          119990
#
#    Operating System  Rating
# 11          Android     4.4
# 15          Android     4.4

# %%
#Box plot to denote average selling prices
fig, ax = plt.subplots(figsize=(20,5))
ax = sns.boxplot(x="Brand", y="Selling Price", data=df_p2,palette=colors)
# Out:
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/2681074858.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x="Brand", y="Selling Price", data=df_p2,palette=colors)
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/2681074858.py:3: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   ax = sns.boxplot(x="Brand", y="Selling Price", data=df_p2,palette=colors)

# %%
sns.barplot(x=df['Operating System'], y=df['Selling Price'],palette=colors)
plt.xticks(rotation="vertical")
plt.show()
# Out:
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/3148093046.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Operating System'], y=df['Selling Price'],palette=colors)
# /var/folders/49/yg3wsvdd3f58h2tww9p8yrn80000gn/T/ipykernel_54257/3148093046.py:1: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=df['Operating System'], y=df['Selling Price'],palette=colors)

# %%
#
